# %%
import xml.dom.minidom

def main():
    company = xml.dom.minidom.parse('Bai2.3_sample.xml')
    # In ten node goc cua tai lieu
    print(company.nodeName)

    # In the goc thu te trong xml
    print(company.documentElement.tagName)
if __name__ == '__main__':
    main()
# Out:
# #document
# Company
