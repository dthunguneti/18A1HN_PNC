# %%
import json

data = {
    'Name': 'Đinh Tiến Hưng',
    'Age': '12/10/2006',
    'Skill': 'Python, AI',
    'Company': '28TECH'
}

# Chuyển đổi đối tượng python sang đối tượng json: 
json_1 = json.dumps(data, ensure_ascii= False)

print(json_1)
# Out:
# {"Name": "Đinh Tiến Hưng", "Age": "12/10/2006", "Skill": "Python, AI", "Company": "28TECH"}
