# %%
import json 

data = {
    'MSV': '24174600037',
    'Class': 'DHKL18A1HN',
    'Name': 'Đinh Tiến Hưng',
    'HomeTown': 'Ninh Bình'
}

# chuyển đối đối tượng python thành đối tượng json: 
json_1 = json.dumps(data, ensure_ascii=False, indent=4)

print(json_1)
# Out:
# {
#     "MSV": "24174600037",
#     "Class": "DHKL18A1HN",
#     "Name": "Đinh Tiến Hưng",
#     "HomeTown": "Ninh Bình"
# }
