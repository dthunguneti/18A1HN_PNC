# %%
import numpy as np
import pandas as pd

ser = pd.Series(list('abcdefghijklmopqrstuvwxyz'))

pos = [0, 4, 8, 14, 20]

# %%
ser[pos]
# Out:
# 0     a
# 4     e
# 8     i
# 14    p
# 20    v
# dtype: object
