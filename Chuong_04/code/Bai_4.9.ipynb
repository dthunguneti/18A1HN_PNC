# %%
import numpy as np
import pandas as pd

ser = pd.Series(np.random.randint(1, 10, 35))

ser

# %% [markdown]
# - Giai thích ý nghĩa mã lệnh trên:
#
# - np.random.randint(1, 10, 35) : Tao một mảng 1 chiều gồm 35 phần tử ngầu nhiên từ 1 - > 10
#
# - pd.Series : Tạo đối tượng Series pandas

# %%
df = ser.values.reshape(7, 5)

data_ser = pd.DataFrame(df)
data_ser
# Out:
#    0  1  2  3  4
# 0  7  6  6  2  6
# 1  6  3  4  1  9
# 2  8  4  2  6  5
# 3  7  9  7  8  8
# 4  8  7  2  3  3
# 5  2  2  3  4  4
# 6  7  9  7  2  1
