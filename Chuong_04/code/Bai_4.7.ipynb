# %%
import numpy as np
import pandas as pd

np.random.RandomState(100)
ser =  pd.Series(np.random.randint(1, 5, [12]))
ser
# Out:
# 0     2
# 1     4
# 2     4
# 3     3
# 4     3
# 5     1
# 6     3
# 7     2
# 8     1
# 9     1
# 10    3
# 11    4
# dtype: int32

# %%
top = ser.value_counts().nlargest(2)
ser.isin(top)

xuat = ser.where(ser.isin(top), 'other')
xuat
# Out:
# 0     other
# 1         4
# 2         4
# 3         3
# 4         3
# 5     other
# 6         3
# 7     other
# 8     other
# 9     other
# 10        3
# 11        4
# dtype: object
