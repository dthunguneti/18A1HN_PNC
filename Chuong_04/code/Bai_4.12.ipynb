# %%
import numpy as np
import pandas as pd

ser_1 = pd.Series(range(5))
ser_2 = pd.Series(list('abcde'))

# %%
ser_1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
ser_2
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
df_1 = pd.concat([ser_1 ,ser_2],axis=0)
df_1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
df_2 = pd.concat([ser_1, ser_2], axis=1)
df_2
# Out:
#    0  1
# 0  0  a
# 1  1  b
# 2  2  c
# 3  3  d
# 4  4  e

# %%
data_df_1 = pd.DataFrame(df_1)
data_df_1
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
# 0  a
# 1  b
# 2  c
# 3  d
# 4  e

# %%
data_df_2 = pd.DataFrame(df_2)
data_df_2
# Out:
#    0  1
# 0  0  a
# 1  1  b
# 2  2  c
# 3  3  d
# 4  4  e
