# %%
import numpy as np 
import pandas as pd

ser = pd.Series(np.random.random(20))

# %%
df = pd.qcut(ser, 10, 
             labels= ['D1', 'D2', 'D3', 'D4', 'D5', 
                      'D6', 'D7', 'D8', 'D9', 'D10'])

df
# Out:
# 0      D9
# 1      D3
# 2      D2
# 3      D5
# 4      D3
# 5      D7
# 6      D5
# 7      D6
# 8      D9
# 9      D1
# 10     D8
# 11     D6
# 12     D8
# 13     D7
# 14    D10
# 15     D4
# 16     D1
# 17     D4
# 18     D2
# 19    D10
# dtype: category
# Categories (10, object): ['D1' < 'D2' < 'D3' < 'D4' ... 'D7' < 'D8' < 'D9' < 'D10']
