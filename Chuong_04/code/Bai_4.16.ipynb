# %%
import pandas as pd

ser = pd.Series([1, 3, 6, 10, 15, 21, 27, 35])
ser
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# 5    21
# 6    27
# 7    35
# dtype: int64

# %% [markdown]
# * Tính hiệu số của hiệu số liên tiếp trong ser

# %%
ser.diff().diff()
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    0.0
# 7    2.0
# dtype: float64
