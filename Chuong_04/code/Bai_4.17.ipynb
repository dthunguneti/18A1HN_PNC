# %%
import pandas as pd

ser = pd.Series(['01 Jan2010', '02-02-2011', '2013/04/04', '2014-05-05', '2015-06-06T12:20'])
df = pd.to_datetime(ser, format='mixed')
df
# Out:
# 0   2010-01-01 00:00:00
# 1   2011-02-02 00:00:00
# 2   2013-04-04 00:00:00
# 3   2014-05-05 00:00:00
# 4   2015-06-06 12:20:00
# dtype: datetime64[ns]
